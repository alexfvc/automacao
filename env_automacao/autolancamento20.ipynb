# %% [markdown]
# instruçoes necessarias
# para lancar notas do primeiro ano temos que colocar a turma 1 reg 6 como última a ser lançada.
# para lancar 2 e terceiros anos temos que colocar as turmas de 3 anos por último na tabela.
#
# isso é importante pois AINDA nao programei para identificr o nome da turma e busca-la automaticamente. (fica pra versao 3.0)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep
import pandas as pd

# %%
class newbot:
    def __init__(self):
        self.driver = webdriver.Chrome()
        
        
    def diario_escolar_login(self):
        print("preencha os campos com seu login, senha e o capchat na pagina do diario que acabou de abrir. \nNAO CLICK EM ENTRAR")          
        site = 'https://www.diarioescolardigital.educacao.mg.gov.br/diarioeletronico-frontend/'
        self.driver.get(site)                                                                                                       
        ja = input("digite  s  ao terminar:\n ")
        if ja == "s":
            self.driver.find_element(
                by=By.XPATH, 
                value='/html/body/div/div/div/div/div/div/div/div/div/div/button').click()                #click em entrar
            self.driver.implicitly_wait(5)    
        else:
            bott = newbot()
            bott.diario_escolar_login()
            
            
    def choice_turma(self):
        nv = input("quer lancar aulas no novo ensino medio? \n se sim entao responda com s \n caso contrario responda com n\n")
        if nv == "s":
            self.navegacao_novo_em()
            self.preencher1()
        elif nv == "n":
            self.navegacao_em()
            self.preencher23()
        else:
            self.choice_turma()
    
            
    def navegacao_novo_em(self):
        self.driver.find_element(
                by=By.XPATH, value='/html/body/div[1]/div/div/div/div/div/div[1]/div[2]/div/div/ul/li[1]/a/span').click()
        self.driver.implicitly_wait(5)
        
        self.driver.find_element(
                by=By.XPATH, value='/html/body/div[1]/div/div/div/div/div/div[1]/div[2]/div/div/ul/li[1]/ul/li[1]/a/span').click()
        self.driver.implicitly_wait(5)
        
        self.driver.find_element(
                by=By.XPATH, value='/html/body/div[1]/div/div/div/div/div/div[2]/div/div/div/div[1]/div[2]/div/button[8]').click()
                                                            #apos essa execucao é so lancar no novo ensino medio(1°s anos)
            
    def navegacao_em(self):
        self.driver.find_element(
                by=By.XPATH, value='/html/body/div[1]/div/div/div/div/div/div[1]/div[2]/div/div/ul/li[2]/a/span').click()
            
        self.driver.find_element(
                by=By.XPATH, value='/html/body/div[1]/div/div/div/div/div/div[2]/div/div/div/div[1]/div[2]/div/button[9]').click()
        sleep(1)                                                 
                                                            #apos essa execucao é so lancar no novo ensino medio(2e3°s anos)
    
    #lancamento 1°        
    def preencher1(self):
        for i, Data in enumerate(tabela["Data"]):
            Turma = tabela.loc[i,"Turma"]
            Disciplina = tabela.loc[i,"Disciplina"]
            EtapadaMatrícula = tabela.loc[i,"EtapadaMatrícula"]
            Bimestre = tabela.loc[i,"Bimestre"]
            ConteudoLecionado = tabela.loc[i, "ConteudoLecionado"]
            self.driver.implicitly_wait(5)
            i6 = 0
            #selecionando Turma
            self.driver.find_element(
                by=By.XPATH, value='/html/body/div[1]/div/div/div/div/div/div[2]/div/div/div/div[3]/div[1]/div[2]/div[1]/div[1]/span[3]/a').click()   #click na pesquisa turma
            sleep(2)
            self.driver.implicitly_wait(5)
            if Turma == "1º EM REG 3 - AVENIDA DELVITO ALVES DA SILVA, 888":                   #click na turma13
                self.driver.find_element(by=By.XPATH, value="/html/body/div[4]/div/div/div[3]/table/tbody[1]/tr[1]/td[1]/div").click()
                sleep(1)
                self.driver.implicitly_wait(5)
            elif Turma == "1º EM REG 5 - AVENIDA DELVITO ALVES DA SILVA, 888":                   #click na turma15
                self.driver.find_element(by=By.XPATH, value="/html/body/div[4]/div/div/div[3]/table/tbody[1]/tr[2]/td[1]/div").click()
                sleep(1)
                self.driver.implicitly_wait(5)
            elif Turma == "1º EM REG 2 - AVENIDA DELVITO ALVES DA SILVA, 888":                   #click na turma12
                self.driver.find_element(by=By.XPATH, value="/html/body/div[4]/div/div/div[3]/table/tbody[1]/tr[3]/td[1]/div").click()
                sleep(1)
                self.driver.implicitly_wait(5)
            elif Turma == "1º EM REG 1 - AVENIDA DELVITO ALVES DA SILVA, 888":                   #click na turma11
                self.driver.find_element(by=By.XPATH, value="/html/body/div[4]/div/div/div[3]/table/tbody[1]/tr[4]/td[1]/div").click()
                sleep(1)
                self.driver.implicitly_wait(5)
            elif Turma == "1º EM REG 4 - AVENIDA DELVITO ALVES DA SILVA, 888":                   #click na turma15
                self.driver.find_element(by=By.XPATH, value="/html/body/div[4]/div/div/div[3]/table/tbody[1]/tr[5]/td[1]/div").click()
                sleep(1)
                self.driver.implicitly_wait(5)
            elif Turma == "1º EM REG 6 - AVENIDA DELVITO ALVES DA SILVA, 888":                   #click na turma16
                if i6 == 0:
                    i6 = i6 + 1
                    self.driver.find_element(by=By.XPATH, value="/html/body/div[4]/div/div/div[4]/div/ul/li[5]/a").click()    #clica na setinha
                    sleep(2)
                    self.driver.find_element(by=By.XPATH, value="/html/body/div[4]/div/div/div[3]/table/tbody[1]/tr/td[1]/div").click()
                    sleep(1)
                    self.driver.implicitly_wait(5)
                else:
                    self.driver.find_element(by=By.XPATH, value="/html/body/div[4]/div/div/div[3]/table/tbody[1]/tr/td[1]/div").click()
                    sleep(1)
                    self.driver.implicitly_wait(5)
            else:
                print(f"turma de 1° nao exite, corigir linha {i} da tabela diario")
                break

            #Disciplina
            if Disciplina == "FÍSICA":
                self.driver.find_element(
                    by=By.XPATH, value='/html/body/div[1]/div/div/div/div/div/div[2]/div/div/div/div[3]/div[1]/div[2]/div[1]/div[2]/span[2]/a/i').click()           
                sleep(1)
                self.driver.implicitly_wait(5)
                self.driver.find_element(
                    by=By.XPATH, value='/html/body/div[4]/div/div/div[3]/table/tbody[1]/tr/td/div').click()           
                self.driver.implicitly_wait(5)
            else:
                print("erro Disciplina")
                break                
                   
            #Etapa da Matrícula
            if EtapadaMatrícula == "1º":
                self.driver.find_element(by=By.XPATH, value='/html/body/div[1]/div/div/div/div/div/div[2]/div/div/div/div[3]/div[1]/div[2]/div[1]/div[3]/span[3]/a/i').click()    
                sleep(1)
                self.driver.implicitly_wait(5)
                self.driver.find_element(by=By.XPATH, value='/html/body/div[1]/div/div/div/div/div/div[2]/div/div/div/div[3]/div[1]/div[2]/div[1]/div[3]/span[3]/a/i').click()                             
                sleep(1)
                self.driver.implicitly_wait(5)
            else:
                print("erro Etapa da Matrícula")
                break
            
            self.driver.find_element(
                by=By.XPATH, value='/html/body/div[1]/div/div/div/div/div/div[2]/div/div/div/div[3]/div[1]/div[2]/div[1]/div[4]/span[2]/a').click()
            sleep(1)
            if Bimestre == "1º BIMESTRE":
                self.driver.find_element(
                    by=By.XPATH, value='/html/body/div[4]/div/div/div[3]/table/tbody[1]/tr[1]/td/div').click()
                sleep(1)
            elif Bimestre == "2º BIMESTRE":
                self.driver.find_element(
                    by=By.XPATH, value='/html/body/div[4]/div/div/div[3]/table/tbody[1]/tr[2]/td/div').click()
                sleep(1)
            elif Bimestre == "3º BIMESTRE":
                self.driver.find_element(
                    by=By.XPATH, value='/html/body/div[4]/div/div/div[3]/table/tbody[1]/tr[3]/td/div').click()
                sleep(1)
            elif Bimestre == "4º BIMESTRE":
                self.driver.find_element(
                    by=By.XPATH, value='/html/body/div[4]/div/div/div[3]/table/tbody[1]/tr[4]/td/div').click()
            else:
                print("erro no campo bimestre")
                break

            #data
            """self.driver.find_element(
                    by=By.XPATH, value='/html/body/div[1]/div/div/div/div/div/div[2]/div/div/div/div[3]/div[1]/div[2]/div[1]/div[5]/span[3]/input').send_keys(str(Data))            """ 
            #ConteudoLecionado
            self.driver.find_element(
                    by=By.XPATH, value='/html/body/div[1]/div/div/div/div/div/div[2]/div/div/div/div[3]/div[1]/div[2]/div[1]/div[6]/input').send_keys(ConteudoLecionado)
            #salvar 
            """self.driver.find_element(
                By.CSS_SELECTOR, '[class="btn btn-default btn-salvar z-button"]').click()"""
            sleep(4)
            self.driver.find_element(
                By.CSS_SELECTOR, '[class="btn btn-default btn-novo z-button"]').click()
            sleep(1)
            print(f"Turma: {Turma}, aula n°{i+1}, {Data} - {ConteudoLecionado}")
            
    #lancamento 2° e 3°
    def preencher23(self):
        for i, Data in enumerate(tabela["Data"]):
            Turma = tabela.loc[i,"Turma"]
            Disciplina = tabela.loc[i,"Disciplina"]
            EtapadaMatrícula = tabela.loc[i,"EtapadaMatrícula"]
            Bimestre = tabela.loc[i,"Bimestre"]
            ConteudoLecionado = tabela.loc[i, "ConteudoLecionado"]
            self.driver.implicitly_wait(5)
            #turma
            if EtapadaMatrícula == "2º":
                self.driver.find_element(
                    by=By.XPATH, value='/html/body/div[1]/div/div/div/div/div/div[2]/div/div/div/div[3]/div[1]/div[2]/div[1]/div[1]/span[3]/a').click()   #click na pesquisa turma
                sleep(2)
                if Turma == "2º EM REG 1 - AVENIDA DELVITO ALVES DA SILVA, 888":                   #click na turma
                    self.driver.find_element(
                        by=By.XPATH, value="/html/body/div[4]/div/div/div[3]/table/tbody[1]/tr[1]/td[1]/div").click()
                    sleep(1)
                elif Turma == "2º EM REG 2 - AVENIDA DELVITO ALVES DA SILVA, 888":                   #click na turma
                    self.driver.find_element(
                        by=By.XPATH, value="/html/body/div[4]/div/div/div[3]/table/tbody[1]/tr[2]/td[1]/div").click()
                    sleep(1)
                elif Turma == "2º EM REG 3 - AVENIDA DELVITO ALVES DA SILVA, 888":                   #click na turma
                    self.driver.find_element(
                        by=By.XPATH, value="/html/body/div[4]/div/div/div[3]/table/tbody[1]/tr[3]/td[1]/div").click()
                    sleep(1)
                elif Turma == "2º EM REG 4 - AVENIDA DELVITO ALVES DA SILVA, 888":                   #click na turma
                    self.driver.find_element(
                        by=By.XPATH, value="/html/body/div[4]/div/div/div[3]/table/tbody[1]/tr[4]/td[1]/div").click()
                    sleep(1)
                elif Turma == "2º EM REG 5 - AVENIDA DELVITO ALVES DA SILVA, 888":                   #click na turma
                    self.driver.find_element(
                        by=By.XPATH, value="/html/body/div[4]/div/div/div[3]/table/tbody[1]/tr[5]/td[1]/div").click()
                    sleep(1)
                else:
                    print(f"turma de 2 nao exite, corigir linha {i} da tabela diario")
                    break
                    
            
            elif EtapadaMatrícula == "3º":
                self.driver.find_element(
                    by=By.XPATH, value='/html/body/div[1]/div/div/div/div/div/div[2]/div/div/div/div[3]/div[1]/div[2]/div[1]/div[1]/span[3]/a').click()   #click na pesquisa turma
                sleep(2)
                if i == 0:                                #apenas a setinha no if, pois ao clicar em novo a aba ja fica certa
                    self.driver.find_element(
                        by=By.XPATH, value="/html/body/div[4]/div/div/div[4]/div/ul/li[5]/a").click() #click na setinha
                    sleep(1)
                if Turma == "3º EM REG 1 - AVENIDA DELVITO ALVES DA SILVA, 888":                   #click na turma
                    self.driver.find_element(
                        by=By.XPATH, value="/html/body/div[4]/div/div/div[3]/table/tbody[1]/tr[1]/td[1]/div").click()
                    sleep(1)
                elif Turma == "3º EM REG 2 - AVENIDA DELVITO ALVES DA SILVA, 888":                   #click na turma
                    self.driver.find_element(
                        by=By.XPATH, value="/html/body/div[4]/div/div/div[3]/table/tbody[1]/tr[2]/td[1]/div").click()
                    sleep(1)
                elif Turma == "3º EM REG 3 - AVENIDA DELVITO ALVES DA SILVA, 888":                   #click na turma
                    self.driver.find_element(
                        by=By.XPATH, value="/html/body/div[4]/div/div/div[3]/table/tbody[1]/tr[3]/td[1]/div").click()
                    sleep(1)
                elif Turma == "3º EM REG 4 - AVENIDA DELVITO ALVES DA SILVA, 888":                   #click na turma
                    self.driver.find_element(
                        by=By.XPATH, value="/html/body/div[4]/div/div/div[3]/table/tbody[1]/tr[4]/td[1]/div").click()
                    sleep(1)
                elif Turma == "3º EM REG 5 - AVENIDA DELVITO ALVES DA SILVA, 888":                   #click na turma
                    self.driver.find_element(
                        by=By.XPATH, value="/html/body/div[4]/div/div/div[3]/table/tbody[1]/tr[5]/td[1]/div").click()
                    sleep(1)
                else:
                    print(f"turma de 3 nao exite, corigir linha {i} da tabela diario")
                    break  
            else:
                print("erro no campo Turma da planilha diário")
                break
            
            #bimestre            
            self.driver.find_element(
                by=By.XPATH, value='/html/body/div[1]/div/div/div/div/div/div[2]/div/div/div/div[3]/div[1]/div[2]/div[1]/div[4]/span[2]/a').click()
            sleep(1)
            if Bimestre == "1º BIMESTRE":
                self.driver.find_element(
                    by=By.XPATH, value='/html/body/div[4]/div/div/div[3]/table/tbody[1]/tr[1]/td/div').click()
                sleep(1)
            elif Bimestre == "2º BIMESTRE":
                self.driver.find_element(
                    by=By.XPATH, value='/html/body/div[4]/div/div/div[3]/table/tbody[1]/tr[2]/td/div').click()
                sleep(1)
            elif Bimestre == "3º BIMESTRE":
                self.driver.find_element(
                    by=By.XPATH, value='/html/body/div[4]/div/div/div[3]/table/tbody[1]/tr[3]/td/div').click()
                sleep(1)
            elif Bimestre == "4º BIMESTRE":
                self.driver.find_element(
                    by=By.XPATH, value='/html/body/div[4]/div/div/div[3]/table/tbody[1]/tr[4]/td/div').click()
            else:
                print("erro no campo bimestre")
                break
            
            #data
            self.driver.find_element(
                    by=By.XPATH, value='/html/body/div[1]/div/div/div/div/div/div[2]/div/div/div/div[3]/div[1]/div[2]/div[1]/div[5]/span[3]/input').send_keys(str(Data))            
            #ConteudoLecionado
            self.driver.find_element(
                    by=By.XPATH, value='/html/body/div[1]/div/div/div/div/div/div[2]/div/div/div/div[3]/div[1]/div[2]/div[1]/div[6]/input').send_keys(ConteudoLecionado)
            #salvar 
            self.driver.find_element(
                By.CSS_SELECTOR, '[class="btn btn-default btn-salvar z-button"]').click()
            sleep(4)
            self.driver.find_element(
                By.CSS_SELECTOR, '[class="btn btn-default btn-novo z-button"]').click()
            sleep(1)
            print(f"Turma: {Turma}, aula n°{i+1}, {Data} - {ConteudoLecionado}")

# %%
tabela = pd.read_excel("diario.xlsx")
tabela['Data'] = tabela['Data'].dt.strftime('%d/%m/%Y')
tabela.info()
tabela.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Turma              105 non-null    object
#  1   Disciplina         105 non-null    object
#  2   EtapadaMatrícula   105 non-null    object
#  3   Bimestre           105 non-null    object
#  4   Data               105 non-null    object
#  5   ConteudoLecionado  105 non-null    object
# dtypes: object(6)
# memory usage: 5.0+ KB
#                                                Turma  \
# 0  2º EM REG 1 - AVENIDA DELVITO ALVES DA SILVA, 888
# 1  2º EM REG 1 - AVENIDA DELVITO ALVES DA SILVA, 888
# 2  2º EM REG 1 - AVENIDA DELVITO ALVES DA SILVA, 888
# 3  2º EM REG 1 - AVENIDA DELVITO ALVES DA SILVA, 888
# 4  2º EM REG 1 - AVENIDA DELVITO ALVES DA SILVA, 888
#
#                   Disciplina EtapadaMatrícula     Bimestre        Data  \
# ...

# %%
bott = newbot()
bott.diario_escolar_login()
bott.choice_turma()
print("FEITO!!!")
# Out:
# preencha os campos com seu login, senha e o capchat na pagina do diario que acabou de abrir.
# NAO CLICK EM ENTRAR
# digite  s  ao terminar:
#  s
# quer lancar aulas no novo ensino medio?
#  se sim entao responda com s
#  caso contrario responda com n
# n
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In [9], line 3
#       1 bott = newbot()
#       2 bott.diario_escolar_login()
# ----> 3 bott.choice_turma()
#       4 print("FEITO!!!")
#
# Cell In [7], line 28, in newbot.choice_turma(self)
#      26 elif nv == "n":
#      27     self.navegacao_em()
# ---> 28     self.preencher23()
#      29 else:
#      30     self.choice_turma()
#
# Cell In [7], line 243, in newbot.preencher23(self)
#     240     break
#     242 #bimestre
# --> 243 self.driver.find_element(
# ...
